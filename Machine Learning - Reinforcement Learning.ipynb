# %%
# Reinforcement Learning

# %% [markdown]
# # Upper Confidence Bound

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

dataset = pd.read_csv("/content/drive/MyDrive/Machine Learning Udemy/Ads_CTR_Optimisation.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Thompson Sampling

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

dataset = pd.read_csv("/content/drive/MyDrive/Machine Learning Udemy/Ads_CTR_Optimisation.csv")
